# %%
import pandas
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

import csv_helper

def predictLabel(username):
	"""
	On récupère les mails non labélisés et labélisés dans des df.
	On fait un TF-IDF pour séparer tous les mots et affiche un "score" pour chacun.
	On fait une régression logistique entre le body et le folder des mails déjà labélisé. Le Folder est seulement le nom d'un label.
	Une fois le classifier créé, on l'applique sur les mails non labélisés et on retourne un dictionnaire contenant tous les labels de prédictions.
	"""
	#On récupère les mails labélisés
	filename = csv_helper.getPath(username)
	csv.field_size_limit(sys.maxsize)
	df = pandas.read_csv(filename, sep=",", engine="python", header=0)
	
	#On récupère les mails non labélisés
	filename = csv_helper.getPath("UNLABELISED_"+username)
	df2 = pandas.read_csv(filename, sep=",", engine="python", header=0)

	#On prépare les arguments
	X = df.drop(['folder'], axis=1)
	y = pandas.DataFrame(df['folder'])

	X_train = X
	y_train = y
	X_test = df2.drop(['Folder'], axis=1)
	
	print('X : {}\nY : {}'.format(X.shape, y.shape))
	print('X_train : {}\nX_test : {}\ny_train : {}\n'.format(X_train.shape, X_test.shape, y_train.shape))

	"""# TF-IDF vectorizer"""

	vectorizer = TfidfVectorizer(analyzer="word")
	X_train_vec = vectorizer.fit_transform(X_train['Message_body'].values.astype('U'))
	X_train_vec = pandas.DataFrame(X_train_vec.todense(), columns=vectorizer.get_feature_names())

	X_test_vec = vectorizer.transform(X_test['Message_body'].values.astype('U'))
	X_test_vec = pandas.DataFrame(X_test_vec.todense(), columns=vectorizer.get_feature_names())
	X_test_vec.shape

	print('X_train_vec {}\nX_test_vec {}'.format(X_train_vec.shape, X_test_vec.shape))

	"""# Logistic regression"""

	classifier = LogisticRegression(class_weight='balanced')
	y_train = np.ravel(y_train)
	print(classifier.fit(X_train_vec, y_train))

	predicts = classifier.predict(X_test_vec)

	return predicts

# %% [markdown]
# ### import mails from csv files

# %%
import pandas
df = pandas.read_csv(filename, sep=",", engine="python", header=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-0e8d3e929f54> in <module>()
#       1 import pandas
# ----> 2 df = pandas.read_csv(filename, sep=",", engine="python", header=0)
#
# ~/Programmes/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/Programmes/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/Programmes/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/Programmes/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1022                                  ' "c", "python", or' ' "python-fwf")'.format(
#    1023                                      engine=engine))
# -> 1024             self._engine = klass(self.f, **self.options)
#    1025
#    1026     def _failover_to_python(self):
#
# ~/Programmes/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, **kwds)
#    2075         f, handles = _get_handle(f, mode, encoding=self.encoding,
#    2076                                  compression=self.compression,
# -> 2077                                  memory_map=self.memory_map)
#    2078         self.handles.extend(handles)
#    2079
#
# ~/Programmes/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     401         elif is_text:
#     402             # Python 3 and no explicit encoding
# --> 403             f = open(path_or_buf, mode, errors='replace')
#     404         else:
#     405             # Python 3 and binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/m1.autolabel1@gmail.com.csv'

# %% [markdown]
# ### show the 5 first lines of the file

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c42a15b2c7cf> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### mail's keys

# %%
for k in df.keys(): print(k)
# Out:
# ARC-Authentication-Results
# ARC-Message-Signature
# ARC-Seal
# Accept-Language
# Authentication-Results
# Body
# Content-Language
# Content-Type
# Content-type
# DKIM-Signature
# Date
# Delivered-To
# Feedback-ID
# Flags
# Folder
# From
# MIME-Version
# Message-ID
# Received
# Received-SPF
# Return-Path
# Subject
# Thread-Index
# Thread-Topic
# To
# X-Account-Notification-Type
# X-Gm-Message-State
# X-Google-DKIM-Signature
# X-Google-Smtp-Source
# X-MS-Exchange-CrossTenant-Network-Message-Id
# X-MS-Exchange-CrossTenant-fromentityheader
# X-MS-Exchange-CrossTenant-id
# X-MS-Exchange-CrossTenant-originalarrivaltime
# X-MS-Exchange-Transport-CrossTenantHeadersStamped
# X-Notifications
# X-OriginatorOrg
# X-Received
# authentication-results
# received-spf
# spamdiagnosticmetadata
# spamdiagnosticoutput
# x-exchange-antispam-report-cfa-test
# x-exchange-antispam-report-test
# x-forefront-antispam-report
# x-forefront-prvs
# x-microsoft-antispam
# x-microsoft-antispam-message-info
# x-microsoft-antispam-prvs
# x-microsoft-exchange-diagnostics
# x-ms-exchange-antispam-srfa-diagnostics
# x-ms-exchange-senderadcheck
# x-ms-office365-filtering-correlation-id
# x-ms-publictraffictype
# x-ms-traffictypediagnostic
# x-originating-ip

# %% [markdown]
# ### normalize the whole dataframe in lowercase

# %%
#df.columns = df.columns.str.lower()
#df.applymap(lambda x : x.lower() if type(x) == str else x)

# merge columns with same name
#df.groupby(df.columns, axis=1).sum()
df.head()
# Out:
#                           ARC-Authentication-Results  \
# 0  i=1; mx.google.com;\n       dkim=pass header.i...
# 1  i=1; mx.google.com;\n       dkim=pass header.i...
# 2  i=1; mx.google.com;\n       dkim=pass header.i...
# 3  i=1; mx.google.com;\n       dkim=pass header.i...
# 4  i=1; mx.google.com;\n       dkim=pass header.i...
#
#                                ARC-Message-Signature  \
# 0  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# 1  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# 2  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# 3  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# 4  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
#
#                                             ARC-Seal Accept-Language  \
# 0  i=1; a=rsa-sha256; t=1540081081; cv=none;\n   ...    fr-FR, en-US
# 1  i=1; a=rsa-sha256; t=1540081093; cv=none;\n   ...    fr-FR, en-US
# 2  i=1; a=rsa-sha256; t=1540081113; cv=none;\n   ...    fr-FR, en-US
# 3  i=1; a=rsa-sha256; t=1541590388; cv=none;\n   ...             NaN
# 4  i=1; a=rsa-sha256; t=1540081113; cv=none;\n   ...    fr-FR, en-US
#
#                               Authentication-Results  \
# 0  mx.google.com;\n       dkim=pass header.i=@Aix...
# 1  mx.google.com;\n       dkim=pass header.i=@Aix...
# 2  mx.google.com;\n       dkim=pass header.i=@Aix...
# 3  mx.google.com;\n       dkim=pass header.i=@acc...
# 4  mx.google.com;\n       dkim=pass header.i=@Aix...
#
#                                                 Body Content-Language  \
# 0            CECI EST LE CONTENU DU MESSAGE TEST 1\n            fr-FR
# 1            CECI EST LE CONTENU DU MESSAGE TEST 2\n            fr-FR
# 2            CECI EST LE CONTENU DU MESSAGE TEST 3\n            fr-FR
# 3  GmailAutoLabel1 M1Luminy\n\nConnexion sur un n...              NaN
# 4            CECI EST LE CONTENU DU MESSAGE TEST 3\n            fr-FR
#
#                                         Content-Type  \
# 0  multipart/alternative;\n\tboundary="_000_MR2P2...
# 1  multipart/alternative;\n\tboundary="_000_MR2P2...
# 2  multipart/alternative;\n\tboundary="_000_MR2P2...
# 3  multipart/alternative; boundary="0000000000007...
# 4  multipart/alternative;\n\tboundary="_000_MR2P2...
#
#                                         Content-type  \
# 0  ['multipart/alternative', 'text/plain', 'text/...
# 1  ['multipart/alternative', 'text/plain', 'text/...
# 2  ['multipart/alternative', 'text/plain', 'text/...
# 3  ['multipart/alternative', 'text/plain', 'text/...
# 4  ['multipart/alternative', 'text/plain', 'text/...
#
#                                       DKIM-Signature       ...         \
# 0  v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...       ...
# 1  v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...       ...
# 2  v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...       ...
# 3  v=1; a=rsa-sha256; c=relaxed/relaxed;\n       ...       ...
# 4  v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...       ...
#
#                                 x-microsoft-antispam  \
# 0  \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
# 1  \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
# 2  \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
# 3                                                NaN
# 4  \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
#
#                    x-microsoft-antispam-message-info  \
# 0  \n mJ1la6nvtaUy/WbE8uYhMi5rkr1KFeNswN5Wc/ZXVrB...
# 1  \n Qhp7BFTBba3hjOxAeQLajnsWYkwwU59C+/lhNqIIlSX...
# 2  \n uYMcgOqS+K34rAWdgeHoU/0kTxQwdIXtEzpueVylKmT...
# 3                                                NaN
# 4  \n uYMcgOqS+K34rAWdgeHoU/0kTxQwdIXtEzpueVylKmT...
#
#                            x-microsoft-antispam-prvs  \
# 0  \n <MR2P264MB00043AD26F3A53DF999EDAC3F7FB0@MR2...
# 1  \n <MR2P264MB00046AB7141FB06FED57D714F7FB0@MR2...
# 2  \n <MR2P264MB00041D284C2D3E3409F47A80F7FB0@MR2...
# 3                                                NaN
# 4  \n <MR2P264MB00041D284C2D3E3409F47A80F7FB0@MR2...
#
#                     x-microsoft-exchange-diagnostics  \
# 0  \n 1;MR2P264MB0004;6:bwdaHGXQKUdfgafShUhw3WwgP...
# 1  \n 1;MR2P264MB0004;6:+/ncjMkhVa8GUaK/E8VPEWdf1...
# 2  \n 1;MR2P264MB0004;6:0NNazhW3jcYcFoqpOF0ua+uNd...
# 3                                                NaN
# 4  \n 1;MR2P264MB0004;6:0NNazhW3jcYcFoqpOF0ua+uNd...
#
#   x-ms-exchange-antispam-srfa-diagnostics x-ms-exchange-senderadcheck  \
# 0                                    SOS;                         1.0
# 1                                    SOS;                         1.0
# 2                                    SOS;                         1.0
# 3                                     NaN                         NaN
# 4                                    SOS;                         1.0
#
#    x-ms-office365-filtering-correlation-id x-ms-publictraffictype  \
# 0     6bd902c1-f992-4584-ba49-08d636eaa684                  Email
# 1     dd30b130-b91e-4ceb-125f-08d636eaae98                  Email
# 2     c74e8fe2-39d7-4b71-9d0d-08d636eabadf                  Email
# 3                                      NaN                    NaN
# 4     c74e8fe2-39d7-4b71-9d0d-08d636eabadf                  Email
#
#   x-ms-traffictypediagnostic x-originating-ip
# 0             MR2P264MB0004:  [78.222.149.58]
# 1             MR2P264MB0004:  [78.222.149.58]
# 2             MR2P264MB0004:  [78.222.149.58]
# 3                        NaN              NaN
# 4             MR2P264MB0004:  [78.222.149.58]
#
# [5 rows x 55 columns]

# %% [markdown]
# ### clean mails to remove missing values

# %%
def get_rid_of_nulls(dataframe):
    for key in dataframe.keys():
        df[key] = df[key].apply(lambda x : x if not pandas.isnull(x) else 'is null value')
    return dataframe

get_rid_of_nulls(df)
df.head()
# Out:
#                           ARC-Authentication-Results  \
# 0  i=1; mx.google.com;\n       dkim=pass header.i...
# 1  i=1; mx.google.com;\n       dkim=pass header.i...
# 2  i=1; mx.google.com;\n       dkim=pass header.i...
# 3  i=1; mx.google.com;\n       dkim=pass header.i...
# 4  i=1; mx.google.com;\n       dkim=pass header.i...
#
#                                ARC-Message-Signature  \
# 0  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# 1  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# 2  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# 3  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# 4  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
#
#                                             ARC-Seal Accept-Language  \
# 0  i=1; a=rsa-sha256; t=1540081081; cv=none;\n   ...    fr-FR, en-US
# 1  i=1; a=rsa-sha256; t=1540081093; cv=none;\n   ...    fr-FR, en-US
# 2  i=1; a=rsa-sha256; t=1540081113; cv=none;\n   ...    fr-FR, en-US
# 3  i=1; a=rsa-sha256; t=1541590388; cv=none;\n   ...   is null value
# 4  i=1; a=rsa-sha256; t=1540081113; cv=none;\n   ...    fr-FR, en-US
#
#                               Authentication-Results  \
# 0  mx.google.com;\n       dkim=pass header.i=@Aix...
# 1  mx.google.com;\n       dkim=pass header.i=@Aix...
# 2  mx.google.com;\n       dkim=pass header.i=@Aix...
# 3  mx.google.com;\n       dkim=pass header.i=@acc...
# 4  mx.google.com;\n       dkim=pass header.i=@Aix...
#
#                                                 Body Content-Language  \
# 0            CECI EST LE CONTENU DU MESSAGE TEST 1\n            fr-FR
# 1            CECI EST LE CONTENU DU MESSAGE TEST 2\n            fr-FR
# 2            CECI EST LE CONTENU DU MESSAGE TEST 3\n            fr-FR
# 3  GmailAutoLabel1 M1Luminy\n\nConnexion sur un n...    is null value
# 4            CECI EST LE CONTENU DU MESSAGE TEST 3\n            fr-FR
#
#                                         Content-Type  \
# 0  multipart/alternative;\n\tboundary="_000_MR2P2...
# 1  multipart/alternative;\n\tboundary="_000_MR2P2...
# 2  multipart/alternative;\n\tboundary="_000_MR2P2...
# 3  multipart/alternative; boundary="0000000000007...
# 4  multipart/alternative;\n\tboundary="_000_MR2P2...
#
#                                         Content-type  \
# 0  ['multipart/alternative', 'text/plain', 'text/...
# 1  ['multipart/alternative', 'text/plain', 'text/...
# 2  ['multipart/alternative', 'text/plain', 'text/...
# 3  ['multipart/alternative', 'text/plain', 'text/...
# 4  ['multipart/alternative', 'text/plain', 'text/...
#
#                                       DKIM-Signature       ...         \
# 0  v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...       ...
# 1  v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...       ...
# 2  v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...       ...
# 3  v=1; a=rsa-sha256; c=relaxed/relaxed;\n       ...       ...
# 4  v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...       ...
#
#                                 x-microsoft-antispam  \
# 0  \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
# 1  \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
# 2  \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
# 3                                      is null value
# 4  \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
#
#                    x-microsoft-antispam-message-info  \
# 0  \n mJ1la6nvtaUy/WbE8uYhMi5rkr1KFeNswN5Wc/ZXVrB...
# 1  \n Qhp7BFTBba3hjOxAeQLajnsWYkwwU59C+/lhNqIIlSX...
# 2  \n uYMcgOqS+K34rAWdgeHoU/0kTxQwdIXtEzpueVylKmT...
# 3                                      is null value
# 4  \n uYMcgOqS+K34rAWdgeHoU/0kTxQwdIXtEzpueVylKmT...
#
#                            x-microsoft-antispam-prvs  \
# 0  \n <MR2P264MB00043AD26F3A53DF999EDAC3F7FB0@MR2...
# 1  \n <MR2P264MB00046AB7141FB06FED57D714F7FB0@MR2...
# 2  \n <MR2P264MB00041D284C2D3E3409F47A80F7FB0@MR2...
# 3                                      is null value
# 4  \n <MR2P264MB00041D284C2D3E3409F47A80F7FB0@MR2...
#
#                     x-microsoft-exchange-diagnostics  \
# 0  \n 1;MR2P264MB0004;6:bwdaHGXQKUdfgafShUhw3WwgP...
# 1  \n 1;MR2P264MB0004;6:+/ncjMkhVa8GUaK/E8VPEWdf1...
# 2  \n 1;MR2P264MB0004;6:0NNazhW3jcYcFoqpOF0ua+uNd...
# 3                                      is null value
# 4  \n 1;MR2P264MB0004;6:0NNazhW3jcYcFoqpOF0ua+uNd...
#
#   x-ms-exchange-antispam-srfa-diagnostics x-ms-exchange-senderadcheck  \
# 0                                    SOS;                           1
# 1                                    SOS;                           1
# 2                                    SOS;                           1
# 3                           is null value               is null value
# 4                                    SOS;                           1
#
#    x-ms-office365-filtering-correlation-id x-ms-publictraffictype  \
# 0     6bd902c1-f992-4584-ba49-08d636eaa684                  Email
# 1     dd30b130-b91e-4ceb-125f-08d636eaae98                  Email
# 2     c74e8fe2-39d7-4b71-9d0d-08d636eabadf                  Email
# 3                            is null value          is null value
# 4     c74e8fe2-39d7-4b71-9d0d-08d636eabadf                  Email
#
#   x-ms-traffictypediagnostic x-originating-ip
# 0             MR2P264MB0004:  [78.222.149.58]
# 1             MR2P264MB0004:  [78.222.149.58]
# 2             MR2P264MB0004:  [78.222.149.58]
# 3              is null value    is null value
# 4             MR2P264MB0004:  [78.222.149.58]
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Suppression des colonnes ayant des valeurs toutes identiques

# %%
def remove_useless_col(dataframe):
    df_test = dataframe.copy()
    alleq = True
    for attribu in df_test:
        base = df_test[attribu][0]
        for donnee in df_test[attribu]:
            if(not donnee.__eq__('is null value') and not base.__eq__(donnee)):
                alleq = False
                break
        if(alleq): 
            del df_test[attribu]
    return df_test

df_test = remove_useless_col(df)
df_test.head()
# Out:
#                           ARC-Authentication-Results  \
# 0  i=1; mx.google.com;\n       dkim=pass header.i...
# 1  i=1; mx.google.com;\n       dkim=pass header.i...
# 2  i=1; mx.google.com;\n       dkim=pass header.i...
# 3  i=1; mx.google.com;\n       dkim=pass header.i...
# 4  i=1; mx.google.com;\n       dkim=pass header.i...
#
#                                ARC-Message-Signature  \
# 0  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# 1  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# 2  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# 3  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# 4  i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
#
#                                             ARC-Seal Accept-Language  \
# 0  i=1; a=rsa-sha256; t=1540081081; cv=none;\n   ...    fr-FR, en-US
# 1  i=1; a=rsa-sha256; t=1540081093; cv=none;\n   ...    fr-FR, en-US
# 2  i=1; a=rsa-sha256; t=1540081113; cv=none;\n   ...    fr-FR, en-US
# 3  i=1; a=rsa-sha256; t=1541590388; cv=none;\n   ...   is null value
# 4  i=1; a=rsa-sha256; t=1540081113; cv=none;\n   ...    fr-FR, en-US
#
#                               Authentication-Results  \
# 0  mx.google.com;\n       dkim=pass header.i=@Aix...
# 1  mx.google.com;\n       dkim=pass header.i=@Aix...
# 2  mx.google.com;\n       dkim=pass header.i=@Aix...
# 3  mx.google.com;\n       dkim=pass header.i=@acc...
# 4  mx.google.com;\n       dkim=pass header.i=@Aix...
#
#                                                 Body Content-Language  \
# 0            CECI EST LE CONTENU DU MESSAGE TEST 1\n            fr-FR
# 1            CECI EST LE CONTENU DU MESSAGE TEST 2\n            fr-FR
# 2            CECI EST LE CONTENU DU MESSAGE TEST 3\n            fr-FR
# 3  GmailAutoLabel1 M1Luminy\n\nConnexion sur un n...    is null value
# 4            CECI EST LE CONTENU DU MESSAGE TEST 3\n            fr-FR
#
#                                         Content-Type  \
# 0  multipart/alternative;\n\tboundary="_000_MR2P2...
# 1  multipart/alternative;\n\tboundary="_000_MR2P2...
# 2  multipart/alternative;\n\tboundary="_000_MR2P2...
# 3  multipart/alternative; boundary="0000000000007...
# 4  multipart/alternative;\n\tboundary="_000_MR2P2...
#
#                                         Content-type  \
# 0  ['multipart/alternative', 'text/plain', 'text/...
# 1  ['multipart/alternative', 'text/plain', 'text/...
# 2  ['multipart/alternative', 'text/plain', 'text/...
# 3  ['multipart/alternative', 'text/plain', 'text/...
# 4  ['multipart/alternative', 'text/plain', 'text/...
#
#                                       DKIM-Signature       ...         \
# 0  v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...       ...
# 1  v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...       ...
# 2  v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...       ...
# 3  v=1; a=rsa-sha256; c=relaxed/relaxed;\n       ...       ...
# 4  v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...       ...
#
#                                 x-microsoft-antispam  \
# 0  \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
# 1  \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
# 2  \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
# 3                                      is null value
# 4  \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
#
#                    x-microsoft-antispam-message-info  \
# 0  \n mJ1la6nvtaUy/WbE8uYhMi5rkr1KFeNswN5Wc/ZXVrB...
# 1  \n Qhp7BFTBba3hjOxAeQLajnsWYkwwU59C+/lhNqIIlSX...
# 2  \n uYMcgOqS+K34rAWdgeHoU/0kTxQwdIXtEzpueVylKmT...
# 3                                      is null value
# 4  \n uYMcgOqS+K34rAWdgeHoU/0kTxQwdIXtEzpueVylKmT...
#
#                            x-microsoft-antispam-prvs  \
# 0  \n <MR2P264MB00043AD26F3A53DF999EDAC3F7FB0@MR2...
# 1  \n <MR2P264MB00046AB7141FB06FED57D714F7FB0@MR2...
# 2  \n <MR2P264MB00041D284C2D3E3409F47A80F7FB0@MR2...
# 3                                      is null value
# 4  \n <MR2P264MB00041D284C2D3E3409F47A80F7FB0@MR2...
#
#                     x-microsoft-exchange-diagnostics  \
# 0  \n 1;MR2P264MB0004;6:bwdaHGXQKUdfgafShUhw3WwgP...
# 1  \n 1;MR2P264MB0004;6:+/ncjMkhVa8GUaK/E8VPEWdf1...
# 2  \n 1;MR2P264MB0004;6:0NNazhW3jcYcFoqpOF0ua+uNd...
# 3                                      is null value
# 4  \n 1;MR2P264MB0004;6:0NNazhW3jcYcFoqpOF0ua+uNd...
#
#   x-ms-exchange-antispam-srfa-diagnostics x-ms-exchange-senderadcheck  \
# 0                                    SOS;                           1
# 1                                    SOS;                           1
# 2                                    SOS;                           1
# 3                           is null value               is null value
# 4                                    SOS;                           1
#
#    x-ms-office365-filtering-correlation-id x-ms-publictraffictype  \
# 0     6bd902c1-f992-4584-ba49-08d636eaa684                  Email
# 1     dd30b130-b91e-4ceb-125f-08d636eaae98                  Email
# 2     c74e8fe2-39d7-4b71-9d0d-08d636eabadf                  Email
# 3                            is null value          is null value
# 4     c74e8fe2-39d7-4b71-9d0d-08d636eabadf                  Email
#
#   x-ms-traffictypediagnostic x-originating-ip
# 0             MR2P264MB0004:  [78.222.149.58]
# 1             MR2P264MB0004:  [78.222.149.58]
# 2             MR2P264MB0004:  [78.222.149.58]
# 3              is null value    is null value
# 4             MR2P264MB0004:  [78.222.149.58]
#
# [5 rows x 55 columns]

# %% [markdown]
# ### get the first mail

# %%
df.loc[0]
# Out:
# ARC-Authentication-Results                           i=1; mx.google.com;\n       dkim=pass header.i...
# ARC-Message-Signature                                i=1; a=rsa-sha256; c=relaxed/relaxed; d=google...
# ARC-Seal                                             i=1; a=rsa-sha256; t=1540081081; cv=none;\n   ...
# Accept-Language                                                                           fr-FR, en-US
# Authentication-Results                               mx.google.com;\n       dkim=pass header.i=@Aix...
# Body                                                           CECI EST LE CONTENU DU MESSAGE TEST 1\n
# Content-Language                                                                                 fr-FR
# Content-Type                                         multipart/alternative;\n\tboundary="_000_MR2P2...
# Content-type                                         ['multipart/alternative', 'text/plain', 'text/...
# DKIM-Signature                                       v=1; a=rsa-sha256; c=relaxed/relaxed;\n d=AixM...
# Date                                                                   Sun, 21 Oct 2018 00:17:56 +0000
# Delivered-To                                                                   m1.autolabel1@gmail.com
# Feedback-ID                                                                              is null value
# Flags                                                                                         ['Seen']
# Folder                                                                                           INBOX
# From                                                         GARCIA Toni <toni.garcia@etu.univ-amu.fr>
# MIME-Version                                                                                         1
# Message-ID                                           \n <MR2P264MB069294C0979B62AFE47A8F11F7FB0@MR2...
# Received                                             by 2002:a02:4d02:0:0:0:0:0 with SMTP id l2-v6c...
# Received-SPF                                         pass (google.com: domain of toni.garcia@etu.un...
# Return-Path                                                              <toni.garcia@etu.univ-amu.fr>
# Subject                                                                                          TEST1
# Thread-Index                                                          AQHUaNN6/ZM922q7806bSVJi9Vg8CA==
# Thread-Topic                                                                                     TEST1
# To                                                   "m1.autolabel1@gmail.com" <m1.autolabel1@gmail...
# X-Account-Notification-Type                                                              is null value
# X-Gm-Message-State                                                                       is null value
# X-Google-DKIM-Signature                                                                  is null value
# X-Google-Smtp-Source                                 ACcGV62Gj2EKkgdx3yIz4NaQRIFB3gpvQNoTwoEH85mr9z...
# X-MS-Exchange-CrossTenant-Network-Message-Id                      6bd902c1-f992-4584-ba49-08d636eaa684
# X-MS-Exchange-CrossTenant-fromentityheader                                                      Hosted
# X-MS-Exchange-CrossTenant-id                                      a9f1c4f7-38f4-4d38-8a3c-4b6dbe981cea
# X-MS-Exchange-CrossTenant-originalarrivaltime                        21 Oct 2018 00:17:56.1576\n (UTC)
# X-MS-Exchange-Transport-CrossTenantHeadersStamped                                        MR2P264MB0004
# X-Notifications                                                                          is null value
# X-OriginatorOrg                                                                        etu.univ-amu.fr
# X-Received                                           by 2002:a63:ef0b:: with SMTP id u11-v6mr377743...
# authentication-results                               mx.google.com;\n       dkim=pass header.i=@Aix...
# received-spf                                         pass (google.com: domain of toni.garcia@etu.un...
# spamdiagnosticmetadata                                                                            NSPM
# spamdiagnosticoutput                                                                              1:99
# x-exchange-antispam-report-cfa-test                  \n BCL:0;PCL:0;RULEID:(6040522)(2401047)(81215...
# x-exchange-antispam-report-test                                                              UriScan:;
# x-forefront-antispam-report                          \n SFV:NSPM;SFS:(10019020)(39850400004)(366004...
# x-forefront-prvs                                                                            083289FD26
# x-microsoft-antispam                                 \n BCL:0;PCL:0;RULEID:(7020095)(4652040)(89892...
# x-microsoft-antispam-message-info                    \n mJ1la6nvtaUy/WbE8uYhMi5rkr1KFeNswN5Wc/ZXVrB...
# x-microsoft-antispam-prvs                            \n <MR2P264MB00043AD26F3A53DF999EDAC3F7FB0@MR2...
# x-microsoft-exchange-diagnostics                     \n 1;MR2P264MB0004;6:bwdaHGXQKUdfgafShUhw3WwgP...
# x-ms-exchange-antispam-srfa-diagnostics                                                           SOS;
# x-ms-exchange-senderadcheck                                                                          1
# x-ms-office365-filtering-correlation-id                           6bd902c1-f992-4584-ba49-08d636eaa684
# x-ms-publictraffictype                                                                           Email
# x-ms-traffictypediagnostic                                                              MR2P264MB0004:
# x-originating-ip                                                                       [78.222.149.58]
# Name: 0, dtype: object

# %% [markdown]
# ### separate data into two parts
# - the mails with labels or folders
# - the mails without

# %%
flags = df['Flags'].drop_duplicates()
folders = df['Folder'].drop_duplicates()

display(flags, folders)
# Out:
# 0    ['Seen']
# Name: Flags, dtype: object
# 0             INBOX
# 4    Test/SousTest1
# 5    Test/SousTest2
# Name: Folder, dtype: object

# %%
"""def get_rid_of_flags_we_dont_care_about(dataframe, flags=['Seen', 'Unseen']):
    for d in dataframe.values():
        print(d)
    return dataframe

df = get_rid_of_flags_we_dont_care_about(df)"""
# Out:
# "def get_rid_of_flags_we_dont_care_about(dataframe, flags=['Seen', 'Unseen']):\n    for d in dataframe.values():\n        print(d)\n    return dataframe\n\ndf = get_rid_of_flags_we_dont_care_about(df)"
